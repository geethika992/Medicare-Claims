# %%
import pandas as pd
import numpy as np
import altair as alt
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.impute import SimpleImputer
from sklearn.preprocessing import OneHotEncoder, LabelEncoder, OrdinalEncoder, StandardScaler
import src.util as util
import yaml
import copy
from tqdm import tqdm
import os
from datetime import datetime

# %%
config_data=util.config_load()

# %% [markdown]
# 1. Function to Read data from the folder

# %%
def read_raw_data(config: dict,filetype) -> pd.DataFrame:
    # Create variable to store raw dataset
    raw_dataset = pd.DataFrame()

    # Raw Dataset Dir
    raw_dataset_dir = config["raw_dataset_dir"]

     # List files in the directory and filter those with filetype in the filename
    files = [f for f in os.listdir(raw_dataset_dir) if filetype in f and f.endswith('.csv')]

    # Process and concatenate each filtered file
    for i in tqdm(files):
        file_path = os.path.join(raw_dataset_dir, i)
        raw_dataset = pd.concat([raw_dataset, pd.read_csv(file_path)], ignore_index=True)


    # Return the concatenated DataFrame
    return raw_dataset

# %%
df_ben=read_raw_data(config_data,'Beneficiary')
df_inp=read_raw_data(config_data,'Inpatient')
df_outp=read_raw_data(config_data,'Outpatient')
# Out:
#   0%|          | 0/1 [00:00<?, ?it/s]
# 100%|██████████| 1/1 [00:00<00:00,  1.67it/s]
# 100%|██████████| 1/1 [00:00<00:00,  3.61it/s]
# 100%|██████████| 1/1 [00:02<00:00,  2.33s/it]

# %%
print(len(df_ben))
print(len(df_inp))
print(len(df_outp))
# Out:
# 138556
# 40474
# 517737

# %% [markdown]
# **Beneficiary File**

# %%
df_ben.dtypes
# Out:
# BeneID                             object
# DOB                                object
# DOD                                object
# Gender                              int64
# Race                                int64
# RenalDiseaseIndicator              object
# State                               int64
# County                              int64
# NoOfMonths_PartACov                 int64
# NoOfMonths_PartBCov                 int64
# ChronicCond_Alzheimer               int64
# ChronicCond_Heartfailure            int64
# ChronicCond_KidneyDisease           int64
# ChronicCond_Cancer                  int64
# ChronicCond_ObstrPulmonary          int64
# ChronicCond_Depression              int64
# ChronicCond_Diabetes                int64
# ChronicCond_IschemicHeart           int64
# ChronicCond_Osteoporasis            int64
# ChronicCond_rheumatoidarthritis     int64
# ChronicCond_stroke                  int64
# IPAnnualReimbursementAmt            int64
# IPAnnualDeductibleAmt               int64
# OPAnnualReimbursementAmt            int64
# OPAnnualDeductibleAmt               int64
# dtype: object

# %%
df_ben.describe(include='all').T
# Out:
#                                     count  unique         top    freq  \
# BeneID                             138556  138556  BENE159198       1
# DOB                                138556     900  1939-10-01     540
# DOD                                  1421      11  2009-12-01     182
# Gender                           138556.0     NaN         NaN     NaN
# Race                             138556.0     NaN         NaN     NaN
# RenalDiseaseIndicator              138556       2           0  118978
# State                            138556.0     NaN         NaN     NaN
# County                           138556.0     NaN         NaN     NaN
# NoOfMonths_PartACov              138556.0     NaN         NaN     NaN
# NoOfMonths_PartBCov              138556.0     NaN         NaN     NaN
# ChronicCond_Alzheimer            138556.0     NaN         NaN     NaN
# ChronicCond_Heartfailure         138556.0     NaN         NaN     NaN
# ChronicCond_KidneyDisease        138556.0     NaN         NaN     NaN
# ChronicCond_Cancer               138556.0     NaN         NaN     NaN
# ChronicCond_ObstrPulmonary       138556.0     NaN         NaN     NaN
# ChronicCond_Depression           138556.0     NaN         NaN     NaN
# ChronicCond_Diabetes             138556.0     NaN         NaN     NaN
# ChronicCond_IschemicHeart        138556.0     NaN         NaN     NaN
# ChronicCond_Osteoporasis         138556.0     NaN         NaN     NaN
# ChronicCond_rheumatoidarthritis  138556.0     NaN         NaN     NaN
# ChronicCond_stroke               138556.0     NaN         NaN     NaN
# IPAnnualReimbursementAmt         138556.0     NaN         NaN     NaN
# IPAnnualDeductibleAmt            138556.0     NaN         NaN     NaN
# OPAnnualReimbursementAmt         138556.0     NaN         NaN     NaN
# OPAnnualDeductibleAmt            138556.0     NaN         NaN     NaN
#
#                                         mean          std     min    25%  \
# BeneID                                   NaN          NaN     NaN    NaN
# DOB                                      NaN          NaN     NaN    NaN
# DOD                                      NaN          NaN     NaN    NaN
# Gender                              1.570932     0.494945     1.0    1.0
# Race                                1.254511     0.717007     1.0    1.0
# RenalDiseaseIndicator                    NaN          NaN     NaN    NaN
# State                              25.666734    15.223443     1.0   11.0
# County                            374.424745   266.277581     0.0  141.0
# NoOfMonths_PartACov                11.907727     1.032332     0.0   12.0
# NoOfMonths_PartBCov                11.910145     0.936893     0.0   12.0
# ChronicCond_Alzheimer               1.667817     0.470998     1.0    1.0
# ChronicCond_Heartfailure            1.506322     0.499962     1.0    1.0
# ChronicCond_KidneyDisease           1.687643     0.463456     1.0    1.0
# ChronicCond_Cancer                  1.880041     0.324914     1.0    2.0
# ChronicCond_ObstrPulmonary          1.762847     0.425339     1.0    2.0
# ChronicCond_Depression              1.644476     0.478674     1.0    1.0
# ChronicCond_Diabetes                1.398142     0.489517     1.0    1.0
# ChronicCond_IschemicHeart           1.324143     0.468056     1.0    1.0
# ChronicCond_Osteoporasis            1.725317     0.446356     1.0    1.0
# ChronicCond_rheumatoidarthritis      1.74318     0.436881     1.0    1.0
# ChronicCond_stroke                  1.920942     0.269831     1.0    2.0
# IPAnnualReimbursementAmt         3660.346502  9568.621827 -8000.0    0.0
# IPAnnualDeductibleAmt             399.847296   956.175202     0.0    0.0
# OPAnnualReimbursementAmt         1298.219348  2493.901134   -70.0  170.0
# OPAnnualDeductibleAmt             377.718258   645.530187     0.0   40.0
#
#                                    50%     75%       max
# BeneID                             NaN     NaN       NaN
# DOB                                NaN     NaN       NaN
# DOD                                NaN     NaN       NaN
# Gender                             2.0     2.0       2.0
# Race                               1.0     1.0       5.0
# RenalDiseaseIndicator              NaN     NaN       NaN
# State                             25.0    39.0      54.0
# County                           340.0   570.0     999.0
# NoOfMonths_PartACov               12.0    12.0      12.0
# NoOfMonths_PartBCov               12.0    12.0      12.0
# ChronicCond_Alzheimer              2.0     2.0       2.0
# ChronicCond_Heartfailure           2.0     2.0       2.0
# ChronicCond_KidneyDisease          2.0     2.0       2.0
# ChronicCond_Cancer                 2.0     2.0       2.0
# ChronicCond_ObstrPulmonary         2.0     2.0       2.0
# ChronicCond_Depression             2.0     2.0       2.0
# ChronicCond_Diabetes               1.0     2.0       2.0
# ChronicCond_IschemicHeart          1.0     2.0       2.0
# ChronicCond_Osteoporasis           2.0     2.0       2.0
# ChronicCond_rheumatoidarthritis    2.0     2.0       2.0
# ChronicCond_stroke                 2.0     2.0       2.0
# IPAnnualReimbursementAmt           0.0  2280.0  161470.0
# IPAnnualDeductibleAmt              0.0  1068.0   38272.0
# OPAnnualReimbursementAmt         570.0  1500.0  102960.0
# OPAnnualDeductibleAmt            170.0   460.0   13840.0

# %%
df_ben.isna().sum()
# Out:
# BeneID                                  0
# DOB                                     0
# DOD                                137135
# Gender                                  0
# Race                                    0
# RenalDiseaseIndicator                   0
# State                                   0
# County                                  0
# NoOfMonths_PartACov                     0
# NoOfMonths_PartBCov                     0
# ChronicCond_Alzheimer                   0
# ChronicCond_Heartfailure                0
# ChronicCond_KidneyDisease               0
# ChronicCond_Cancer                      0
# ChronicCond_ObstrPulmonary              0
# ChronicCond_Depression                  0
# ChronicCond_Diabetes                    0
# ChronicCond_IschemicHeart               0
# ChronicCond_Osteoporasis                0
# ChronicCond_rheumatoidarthritis         0
# ChronicCond_stroke                      0
# IPAnnualReimbursementAmt                0
# IPAnnualDeductibleAmt                   0
# OPAnnualReimbursementAmt                0
# OPAnnualDeductibleAmt                   0
# dtype: int64

# %%
df_ben_copy=df_ben.copy()

# %% [markdown]
# 2. Convert the datatype of fields appropriately. The fields are mentioned in config file.

# %%
def type_conv(set_data, config_data,datetime_columns,obj_columns,int_columns):
  
    
    # --- Convert columns to datetime format --- #
    for col in config_data[datetime_columns]:
        if set_data[col].dtype != 'datetime64[ns]':
            set_data[col] = pd.to_datetime(set_data[col])

    # --- Convert specified columns to object type --- #
    for col in config_data[obj_columns]:
        if set_data[col].dtype != 'object':
                set_data[col] = set_data[col].astype(str)

    # --- Convert specified float columns to integer format --- #
    for col in config_data[int_columns]:
        set_data[col]=set_data[col].fillna(0)
        if set_data[col].dtype != 'int64':
            set_data[col] = set_data[col].astype(int)

    # --- Return the modified DataFrame --- #
    return set_data

# %%
df_ben_conv=type_conv(df_ben,config_data,"datetime_columns_ben","obj_columns_ben","int_columns_ben")

# %%
df_ben_conv.dtypes
# Out:
# BeneID                                     object
# DOB                                datetime64[ns]
# DOD                                datetime64[ns]
# Gender                                     object
# Race                                       object
# RenalDiseaseIndicator                      object
# State                                       int64
# County                                      int64
# NoOfMonths_PartACov                         int64
# NoOfMonths_PartBCov                         int64
# ChronicCond_Alzheimer                       int64
# ChronicCond_Heartfailure                    int64
# ChronicCond_KidneyDisease                   int64
# ChronicCond_Cancer                          int64
# ChronicCond_ObstrPulmonary                  int64
# ChronicCond_Depression                      int64
# ChronicCond_Diabetes                        int64
# ChronicCond_IschemicHeart                   int64
# ChronicCond_Osteoporasis                    int64
# ChronicCond_rheumatoidarthritis             int64
# ChronicCond_stroke                          int64
# IPAnnualReimbursementAmt                    int64
# IPAnnualDeductibleAmt                       int64
# OPAnnualReimbursementAmt                    int64
# OPAnnualDeductibleAmt                       int64
# dtype: object

# %%
df_ben_conv.describe(include='all').T
# Out:
#                                     count  unique         top    freq  \
# BeneID                             138556  138556  BENE159198       1
# DOB                                138556     NaN         NaN     NaN
# DOD                                  1421     NaN         NaN     NaN
# Gender                             138556       2           2   79106
# Race                               138556       4           1  117057
# RenalDiseaseIndicator              138556       2           0  118978
# State                            138556.0     NaN         NaN     NaN
# County                           138556.0     NaN         NaN     NaN
# NoOfMonths_PartACov              138556.0     NaN         NaN     NaN
# NoOfMonths_PartBCov              138556.0     NaN         NaN     NaN
# ChronicCond_Alzheimer            138556.0     NaN         NaN     NaN
# ChronicCond_Heartfailure         138556.0     NaN         NaN     NaN
# ChronicCond_KidneyDisease        138556.0     NaN         NaN     NaN
# ChronicCond_Cancer               138556.0     NaN         NaN     NaN
# ChronicCond_ObstrPulmonary       138556.0     NaN         NaN     NaN
# ChronicCond_Depression           138556.0     NaN         NaN     NaN
# ChronicCond_Diabetes             138556.0     NaN         NaN     NaN
# ChronicCond_IschemicHeart        138556.0     NaN         NaN     NaN
# ChronicCond_Osteoporasis         138556.0     NaN         NaN     NaN
# ChronicCond_rheumatoidarthritis  138556.0     NaN         NaN     NaN
# ChronicCond_stroke               138556.0     NaN         NaN     NaN
# IPAnnualReimbursementAmt         138556.0     NaN         NaN     NaN
# IPAnnualDeductibleAmt            138556.0     NaN         NaN     NaN
# OPAnnualReimbursementAmt         138556.0     NaN         NaN     NaN
# OPAnnualDeductibleAmt            138556.0     NaN         NaN     NaN
#
#                                                           mean  \
# BeneID                                                     NaN
# DOB                              1936-04-30 16:46:00.772539520
# DOD                              2009-07-27 22:27:46.995073792
# Gender                                                     NaN
# Race                                                       NaN
# RenalDiseaseIndicator                                      NaN
# State                                                25.666734
# County                                              374.424745
# NoOfMonths_PartACov                                  11.907727
# NoOfMonths_PartBCov                                  11.910145
# ChronicCond_Alzheimer                                 1.667817
# ChronicCond_Heartfailure                              1.506322
# ChronicCond_KidneyDisease                             1.687643
# ChronicCond_Cancer                                    1.880041
# ChronicCond_ObstrPulmonary                            1.762847
# ChronicCond_Depression                                1.644476
# ChronicCond_Diabetes                                  1.398142
# ChronicCond_IschemicHeart                             1.324143
# ChronicCond_Osteoporasis                              1.725317
# ChronicCond_rheumatoidarthritis                        1.74318
# ChronicCond_stroke                                    1.920942
# IPAnnualReimbursementAmt                           3660.346502
# IPAnnualDeductibleAmt                               399.847296
# OPAnnualReimbursementAmt                           1298.219348
# OPAnnualDeductibleAmt                               377.718258
#
#                                                  min                  25%  \
# BeneID                                           NaN                  NaN
# DOB                              1909-01-01 00:00:00  1928-01-01 00:00:00
# DOD                              2009-02-01 00:00:00  2009-06-01 00:00:00
# Gender                                           NaN                  NaN
# Race                                             NaN                  NaN
# RenalDiseaseIndicator                            NaN                  NaN
# State                                            1.0                 11.0
# County                                           0.0                141.0
# NoOfMonths_PartACov                              0.0                 12.0
# NoOfMonths_PartBCov                              0.0                 12.0
# ChronicCond_Alzheimer                            1.0                  1.0
# ChronicCond_Heartfailure                         1.0                  1.0
# ChronicCond_KidneyDisease                        1.0                  1.0
# ChronicCond_Cancer                               1.0                  2.0
# ChronicCond_ObstrPulmonary                       1.0                  2.0
# ChronicCond_Depression                           1.0                  1.0
# ChronicCond_Diabetes                             1.0                  1.0
# ChronicCond_IschemicHeart                        1.0                  1.0
# ChronicCond_Osteoporasis                         1.0                  1.0
# ChronicCond_rheumatoidarthritis                  1.0                  1.0
# ChronicCond_stroke                               1.0                  2.0
# IPAnnualReimbursementAmt                     -8000.0                  0.0
# IPAnnualDeductibleAmt                            0.0                  0.0
# OPAnnualReimbursementAmt                       -70.0                170.0
# OPAnnualDeductibleAmt                            0.0                 40.0
#
#                                                  50%                  75%  \
# BeneID                                           NaN                  NaN
# DOB                              1935-09-01 00:00:00  1941-12-01 00:00:00
# DOD                              2009-08-01 00:00:00  2009-10-01 00:00:00
# Gender                                           NaN                  NaN
# Race                                             NaN                  NaN
# RenalDiseaseIndicator                            NaN                  NaN
# State                                           25.0                 39.0
# County                                         340.0                570.0
# NoOfMonths_PartACov                             12.0                 12.0
# NoOfMonths_PartBCov                             12.0                 12.0
# ChronicCond_Alzheimer                            2.0                  2.0
# ChronicCond_Heartfailure                         2.0                  2.0
# ChronicCond_KidneyDisease                        2.0                  2.0
# ChronicCond_Cancer                               2.0                  2.0
# ChronicCond_ObstrPulmonary                       2.0                  2.0
# ChronicCond_Depression                           2.0                  2.0
# ChronicCond_Diabetes                             1.0                  2.0
# ChronicCond_IschemicHeart                        1.0                  2.0
# ChronicCond_Osteoporasis                         2.0                  2.0
# ChronicCond_rheumatoidarthritis                  2.0                  2.0
# ChronicCond_stroke                               2.0                  2.0
# IPAnnualReimbursementAmt                         0.0               2280.0
# IPAnnualDeductibleAmt                            0.0               1068.0
# OPAnnualReimbursementAmt                       570.0               1500.0
# OPAnnualDeductibleAmt                          170.0                460.0
#
#                                                  max          std
# BeneID                                           NaN          NaN
# DOB                              1983-12-01 00:00:00          NaN
# DOD                              2009-12-01 00:00:00          NaN
# Gender                                           NaN          NaN
# Race                                             NaN          NaN
# RenalDiseaseIndicator                            NaN          NaN
# State                                           54.0    15.223443
# County                                         999.0   266.277581
# NoOfMonths_PartACov                             12.0     1.032332
# NoOfMonths_PartBCov                             12.0     0.936893
# ChronicCond_Alzheimer                            2.0     0.470998
# ChronicCond_Heartfailure                         2.0     0.499962
# ChronicCond_KidneyDisease                        2.0     0.463456
# ChronicCond_Cancer                               2.0     0.324914
# ChronicCond_ObstrPulmonary                       2.0     0.425339
# ChronicCond_Depression                           2.0     0.478674
# ChronicCond_Diabetes                             2.0     0.489517
# ChronicCond_IschemicHeart                        2.0     0.468056
# ChronicCond_Osteoporasis                         2.0     0.446356
# ChronicCond_rheumatoidarthritis                  2.0     0.436881
# ChronicCond_stroke                               2.0     0.269831
# IPAnnualReimbursementAmt                    161470.0  9568.621827
# IPAnnualDeductibleAmt                        38272.0   956.175202
# OPAnnualReimbursementAmt                    102960.0  2493.901134
# OPAnnualDeductibleAmt                        13840.0   645.530187

# %% [markdown]
# 3. Adding Features in beneficiary Table

# %%
def feature_addition_ben(dataset_conv):
    #Age from max value from set
    max_bene_DOD = max(dataset_conv['DOD'].dropna().unique()[1:])
    dataset_conv['DOD_imputed']=dataset_conv['DOD']
    dataset_conv['DOD_imputed']=dataset_conv['DOD_imputed'].apply(lambda i: i if pd.notna(i)  else max_bene_DOD )
    dataset_conv['AGE'] = np.round(((dataset_conv['DOD_imputed'] - dataset_conv['DOB']).dt.days)/365.0,1)
    dataset_conv['AGE']= dataset_conv['AGE'].astype('int64')
    dataset_conv['DOD_Flag']=dataset_conv['DOD'].apply(lambda i: 1 if pd.notna(i)  else 0 )
    dataset_conv['DOD_Flag']= dataset_conv['DOD_Flag'].astype('object')
    dataset_conv['TotalIPAnnualAmt']=dataset_conv['IPAnnualReimbursementAmt']+dataset_conv['IPAnnualReimbursementAmt']
    dataset_conv['TotalOPAnnualAmt']= dataset_conv['OPAnnualReimbursementAmt']+dataset_conv['OPAnnualDeductibleAmt']
    dataset_conv.drop(columns=['DOB','DOD','DOD_imputed'],axis=1,inplace=True)

# %%
feature_addition_ben(df_ben_conv)

# %%
def col_separation(dataset):
    cat_cols=dataset.select_dtypes('object').columns.to_list()
    int_cols=dataset.select_dtypes('int64').columns.to_list()
    time_cols=dataset.select_dtypes('datetime64[ns]').columns.to_list()
    return cat_cols,int_cols,time_cols

# %%
cat_cols=col_separation(df_ben_conv)[0]
int_cols=col_separation(df_ben_conv)[1]
tim_cols=col_separation(df_ben_conv)[2]

# %% [markdown]
# 5. Univariate Analysis

# %%
#Check the distinct value in each field and count of each of them.
for i in cat_cols:
  print("-------",i,"--------")
  print(df_ben_conv[i].value_counts(dropna=False))
# Out:
# ------- BeneID --------
# BeneID
# BENE159198    1
# BENE11001     1
# BENE11002     1
# BENE11003     1
# BENE11004     1
#              ..
# BENE11034     1
# BENE11036     1
# BENE11037     1
# BENE11038     1
# BENE11039     1
# Name: count, Length: 138556, dtype: int64
# ------- Gender --------
# Gender
# 2    79106
# 1    59450
# Name: count, dtype: int64
# ------- Race --------
# Race
# 1    117057
# 2     13538
# 3      5059
# 5      2902
# Name: count, dtype: int64
# ------- RenalDiseaseIndicator --------
# RenalDiseaseIndicator
# 0    118978
# Y     19578
# Name: count, dtype: int64
# ------- ChronicCond_Alzheimer --------
# ChronicCond_Alzheimer
# 2    92530
# 1    46026
# Name: count, dtype: int64
# ------- ChronicCond_Heartfailure --------
# ChronicCond_Heartfailure
# 2    70154
# 1    68402
# Name: count, dtype: int64
# ------- ChronicCond_KidneyDisease --------
# ChronicCond_KidneyDisease
# 2    95277
# 1    43279
# Name: count, dtype: int64
# ------- ChronicCond_Cancer --------
# ChronicCond_Cancer
# 2    121935
# 1     16621
# Name: count, dtype: int64
# ------- ChronicCond_ObstrPulmonary --------
# ChronicCond_ObstrPulmonary
# 2    105697
# 1     32859
# Name: count, dtype: int64
# ------- ChronicCond_Depression --------
# ChronicCond_Depression
# 2    89296
# 1    49260
# Name: count, dtype: int64
# ------- ChronicCond_Diabetes --------
# ChronicCond_Diabetes
# 1    83391
# 2    55165
# Name: count, dtype: int64
# ------- ChronicCond_IschemicHeart --------
# ChronicCond_IschemicHeart
# 1    93644
# 2    44912
# Name: count, dtype: int64
# ------- ChronicCond_Osteoporasis --------
# ChronicCond_Osteoporasis
# 2    100497
# 1     38059
# Name: count, dtype: int64
# ------- ChronicCond_rheumatoidarthritis --------
# ChronicCond_rheumatoidarthritis
# 2    102972
# 1     35584
# Name: count, dtype: int64
# ------- ChronicCond_stroke --------
# ChronicCond_stroke
# 2    127602
# 1     10954
# Name: count, dtype: int64
# ------- DOD_Flag --------
# DOD_Flag
# 0    137135
# 1      1421
# Name: count, dtype: int64

# %%
def cat_columns_univariate (df):
    sns.set_theme(style="whitegrid")
    # Loop through categorical columns
    for i in cat_cols:
        if df[i].nunique() < 10:
            fig, ax = plt.subplots(figsize=(10, 8))
            ax = sns.countplot(data=df, x=i)

            # Calculate percentages
            total = float(len(df))
            for p in ax.patches:
                percentage = '{:.1f}%'.format(100 * p.get_height() / total)
                x = p.get_x() + p.get_width() / 2 - 0.05
                y = p.get_height()
                ax.annotate(percentage, (x, y), ha='center', va='bottom')

            plt.show()
        elif 10 < df[i].nunique() < 30:
        # Get the sorted value counts
            value_counts = df[i].value_counts().sort_values()
            sorted_df = pd.DataFrame({i: value_counts.index, 'count': value_counts.values})

            fig, ax = plt.subplots(figsize=(10, 8))
            sns.countplot(data=df, y=i, order=sorted_df[i], ax=ax)

        # Calculate percentages
            total = float(len(df))
            for p in ax.patches:
                percentage = '{:.1f}%'.format(100 * p.get_width() / total)
                x = p.get_width() + 2.5
                y = p.get_y() + p.get_height() / 2
                ax.annotate(percentage, (x, y), ha='center', va='center')

            plt.show()
    else:
        pass

# %%
cat_columns_univariate(df_ben_conv)

# %%
def num_univariate(df):
    for i in int_cols:
        fig, ax = plt.subplots(figsize=(10, 8))
        sns.histplot(data=df, x=i, bins=5,  kde=True)

# %%
num_univariate(df_ben_conv)

# %% [markdown]
# 6. Outlier Analysis

# %%
def outlier_analysis(df):
    for i in int_cols:
        sns.boxplot(data=df[i])
        plt.show()

# %%
outlier_analysis(df_ben_conv)

# %% [markdown]
# **In Patient File**

# %%
df_inp.dtypes
# Out:
# BeneID                     object
# ClaimID                    object
# ClaimStartDt               object
# ClaimEndDt                 object
# Provider                   object
# InscClaimAmtReimbursed      int64
# AttendingPhysician         object
# OperatingPhysician         object
# OtherPhysician             object
# AdmissionDt                object
# ClmAdmitDiagnosisCode      object
# DeductibleAmtPaid         float64
# DischargeDt                object
# DiagnosisGroupCode         object
# ClmDiagnosisCode_1         object
# ClmDiagnosisCode_2         object
# ClmDiagnosisCode_3         object
# ClmDiagnosisCode_4         object
# ClmDiagnosisCode_5         object
# ClmDiagnosisCode_6         object
# ClmDiagnosisCode_7         object
# ClmDiagnosisCode_8         object
# ClmDiagnosisCode_9         object
# ClmDiagnosisCode_10        object
# ClmProcedureCode_1        float64
# ClmProcedureCode_2        float64
# ClmProcedureCode_3        float64
# ClmProcedureCode_4        float64
# ClmProcedureCode_5        float64
# ClmProcedureCode_6        float64
# dtype: object

# %%
df_inp.describe(include='all').T
# Out:
#                           count unique         top  freq          mean  \
# BeneID                    40474  31289  BENE134170     8           NaN
# ClaimID                   40474  40474    CLM69948     1           NaN
# ClaimStartDt              40474    398  2009-02-10   145           NaN
# ClaimEndDt                40474    365  2009-02-11   153           NaN
# Provider                  40474   2092    PRV52019   516           NaN
# InscClaimAmtReimbursed  40474.0    NaN         NaN   NaN  10087.884074
# AttendingPhysician        40362  11604   PHY422134   386           NaN
# OperatingPhysician        23830   8287   PHY429430   225           NaN
# OtherPhysician             4690   2877   PHY416093    81           NaN
# AdmissionDt               40474    398  2009-02-10   144           NaN
# ClmAdmitDiagnosisCode     40474   1928       78650  1731           NaN
# DeductibleAmtPaid       39575.0    NaN         NaN   NaN        1068.0
# DischargeDt               40474    365  2009-02-11   153           NaN
# DiagnosisGroupCode        40474    736         882   179           NaN
# ClmDiagnosisCode_1        40474   2254         486  1499           NaN
# ClmDiagnosisCode_2        40248   2439        4019  2484           NaN
# ClmDiagnosisCode_3        39798   2427        4019  2282           NaN
# ClmDiagnosisCode_4        38940   2441        4019  2100           NaN
# ClmDiagnosisCode_5        37580   2374        4019  1889           NaN
# ClmDiagnosisCode_6        35636   2358        4019  1620           NaN
# ClmDiagnosisCode_7        33216   2310        4019  1402           NaN
# ClmDiagnosisCode_8        30532   2243        4019  1200           NaN
# ClmDiagnosisCode_9        26977   2094        4019   965           NaN
# ClmDiagnosisCode_10        3927    952        4019   128           NaN
# ClmProcedureCode_1      23148.0    NaN         NaN   NaN   5894.611759
# ClmProcedureCode_2       5454.0    NaN         NaN   NaN   4103.738174
# ClmProcedureCode_3        965.0    NaN         NaN   NaN    4226.35544
# ClmProcedureCode_4        116.0    NaN         NaN   NaN   4070.172414
# ClmProcedureCode_5          9.0    NaN         NaN   NaN   5269.444444
# ClmProcedureCode_6          0.0    NaN         NaN   NaN           NaN
#
#                                  std     min      25%     50%      75%  \
# BeneID                           NaN     NaN      NaN     NaN      NaN
# ClaimID                          NaN     NaN      NaN     NaN      NaN
# ClaimStartDt                     NaN     NaN      NaN     NaN      NaN
# ClaimEndDt                       NaN     NaN      NaN     NaN      NaN
# Provider                         NaN     NaN      NaN     NaN      NaN
# InscClaimAmtReimbursed  10303.099402     0.0   4000.0  7000.0  12000.0
# AttendingPhysician               NaN     NaN      NaN     NaN      NaN
# OperatingPhysician               NaN     NaN      NaN     NaN      NaN
# OtherPhysician                   NaN     NaN      NaN     NaN      NaN
# AdmissionDt                      NaN     NaN      NaN     NaN      NaN
# ClmAdmitDiagnosisCode            NaN     NaN      NaN     NaN      NaN
# DeductibleAmtPaid                0.0  1068.0   1068.0  1068.0   1068.0
# DischargeDt                      NaN     NaN      NaN     NaN      NaN
# DiagnosisGroupCode               NaN     NaN      NaN     NaN      NaN
# ClmDiagnosisCode_1               NaN     NaN      NaN     NaN      NaN
# ClmDiagnosisCode_2               NaN     NaN      NaN     NaN      NaN
# ClmDiagnosisCode_3               NaN     NaN      NaN     NaN      NaN
# ClmDiagnosisCode_4               NaN     NaN      NaN     NaN      NaN
# ClmDiagnosisCode_5               NaN     NaN      NaN     NaN      NaN
# ClmDiagnosisCode_6               NaN     NaN      NaN     NaN      NaN
# ClmDiagnosisCode_7               NaN     NaN      NaN     NaN      NaN
# ClmDiagnosisCode_8               NaN     NaN      NaN     NaN      NaN
# ClmDiagnosisCode_9               NaN     NaN      NaN     NaN      NaN
# ClmDiagnosisCode_10              NaN     NaN      NaN     NaN      NaN
# ClmProcedureCode_1         3049.3044    11.0   3848.0  5369.0  8666.25
# ClmProcedureCode_2       2028.182156    42.0   2724.0  4019.0   4439.0
# ClmProcedureCode_3       2282.761581    42.0   2724.0  4019.0   5185.0
# ClmProcedureCode_4       1994.409802    42.0  2758.75  4019.0   4439.0
# ClmProcedureCode_5       2780.071632  2724.0   4139.0  4139.0   5185.0
# ClmProcedureCode_6               NaN     NaN      NaN     NaN      NaN
#
#                              max
# BeneID                       NaN
# ClaimID                      NaN
# ClaimStartDt                 NaN
# ClaimEndDt                   NaN
# Provider                     NaN
# InscClaimAmtReimbursed  125000.0
# AttendingPhysician           NaN
# OperatingPhysician           NaN
# OtherPhysician               NaN
# AdmissionDt                  NaN
# ClmAdmitDiagnosisCode        NaN
# DeductibleAmtPaid         1068.0
# DischargeDt                  NaN
# DiagnosisGroupCode           NaN
# ClmDiagnosisCode_1           NaN
# ClmDiagnosisCode_2           NaN
# ClmDiagnosisCode_3           NaN
# ClmDiagnosisCode_4           NaN
# ClmDiagnosisCode_5           NaN
# ClmDiagnosisCode_6           NaN
# ClmDiagnosisCode_7           NaN
# ClmDiagnosisCode_8           NaN
# ClmDiagnosisCode_9           NaN
# ClmDiagnosisCode_10          NaN
# ClmProcedureCode_1        9999.0
# ClmProcedureCode_2        9999.0
# ClmProcedureCode_3        9999.0
# ClmProcedureCode_4        9986.0
# ClmProcedureCode_5        9982.0
# ClmProcedureCode_6           NaN

# %%
df_inp.isna().sum()
# Out:
# BeneID                        0
# ClaimID                       0
# ClaimStartDt                  0
# ClaimEndDt                    0
# Provider                      0
# InscClaimAmtReimbursed        0
# AttendingPhysician          112
# OperatingPhysician        16644
# OtherPhysician            35784
# AdmissionDt                   0
# ClmAdmitDiagnosisCode         0
# DeductibleAmtPaid           899
# DischargeDt                   0
# DiagnosisGroupCode            0
# ClmDiagnosisCode_1            0
# ClmDiagnosisCode_2          226
# ClmDiagnosisCode_3          676
# ClmDiagnosisCode_4         1534
# ClmDiagnosisCode_5         2894
# ClmDiagnosisCode_6         4838
# ClmDiagnosisCode_7         7258
# ClmDiagnosisCode_8         9942
# ClmDiagnosisCode_9        13497
# ClmDiagnosisCode_10       36547
# ClmProcedureCode_1        17326
# ClmProcedureCode_2        35020
# ClmProcedureCode_3        39509
# ClmProcedureCode_4        40358
# ClmProcedureCode_5        40465
# ClmProcedureCode_6        40474
# dtype: int64

# %% [markdown]
# 1. Convert the file to pappropriate datatypes.

# %%
df_inp_conv=type_conv(df_inp,config_data,"datetime_columns_inp","obj_columns_inp","int_columns_inp")

# %%
df_inp_conv.dtypes
# Out:
# BeneID                            object
# ClaimID                           object
# ClaimStartDt              datetime64[ns]
# ClaimEndDt                datetime64[ns]
# Provider                          object
# InscClaimAmtReimbursed             int64
# AttendingPhysician                object
# OperatingPhysician                object
# OtherPhysician                    object
# AdmissionDt               datetime64[ns]
# ClmAdmitDiagnosisCode             object
# DeductibleAmtPaid                  int64
# DischargeDt               datetime64[ns]
# DiagnosisGroupCode                object
# ClmDiagnosisCode_1                object
# ClmDiagnosisCode_2                object
# ClmDiagnosisCode_3                object
# ClmDiagnosisCode_4                object
# ClmDiagnosisCode_5                object
# ClmDiagnosisCode_6                object
# ClmDiagnosisCode_7                object
# ClmDiagnosisCode_8                object
# ClmDiagnosisCode_9                object
# ClmDiagnosisCode_10               object
# ClmProcedureCode_1                object
# ClmProcedureCode_2                object
# ClmProcedureCode_3                object
# ClmProcedureCode_4                object
# ClmProcedureCode_5                object
# ClmProcedureCode_6                object
# dtype: object

# %%
df_inp_conv.isna().sum()
# Out:
# BeneID                        0
# ClaimID                       0
# ClaimStartDt                  0
# ClaimEndDt                    0
# Provider                      0
# InscClaimAmtReimbursed        0
# AttendingPhysician          112
# OperatingPhysician        16644
# OtherPhysician            35784
# AdmissionDt                   0
# ClmAdmitDiagnosisCode         0
# DeductibleAmtPaid             0
# DischargeDt                   0
# DiagnosisGroupCode            0
# ClmDiagnosisCode_1            0
# ClmDiagnosisCode_2          226
# ClmDiagnosisCode_3          676
# ClmDiagnosisCode_4         1534
# ClmDiagnosisCode_5         2894
# ClmDiagnosisCode_6         4838
# ClmDiagnosisCode_7         7258
# ClmDiagnosisCode_8         9942
# ClmDiagnosisCode_9        13497
# ClmDiagnosisCode_10       36547
# ClmProcedureCode_1            0
# ClmProcedureCode_2            0
# ClmProcedureCode_3            0
# ClmProcedureCode_4            0
# ClmProcedureCode_5            0
# ClmProcedureCode_6            0
# dtype: int64

# %%
df_inp_conv.describe(include='all').T
# Out:
#                           count unique         top   freq  \
# BeneID                    40474  31289  BENE134170      8
# ClaimID                   40474  40474    CLM69948      1
# ClaimStartDt              40474    NaN         NaN    NaN
# ClaimEndDt                40474    NaN         NaN    NaN
# Provider                  40474   2092    PRV52019    516
# InscClaimAmtReimbursed  40474.0    NaN         NaN    NaN
# AttendingPhysician        40362  11604   PHY422134    386
# OperatingPhysician        23830   8287   PHY429430    225
# OtherPhysician             4690   2877   PHY416093     81
# AdmissionDt               40474    NaN         NaN    NaN
# ClmAdmitDiagnosisCode     40474   1928       78650   1731
# DeductibleAmtPaid       40474.0    NaN         NaN    NaN
# DischargeDt               40474    NaN         NaN    NaN
# DiagnosisGroupCode        40474    736         882    179
# ClmDiagnosisCode_1        40474   2254         486   1499
# ClmDiagnosisCode_2        40248   2439        4019   2484
# ClmDiagnosisCode_3        39798   2427        4019   2282
# ClmDiagnosisCode_4        38940   2441        4019   2100
# ClmDiagnosisCode_5        37580   2374        4019   1889
# ClmDiagnosisCode_6        35636   2358        4019   1620
# ClmDiagnosisCode_7        33216   2310        4019   1402
# ClmDiagnosisCode_8        30532   2243        4019   1200
# ClmDiagnosisCode_9        26977   2094        4019    965
# ClmDiagnosisCode_10        3927    952        4019    128
# ClmProcedureCode_1        40474   1118         nan  17326
# ClmProcedureCode_2        40474    298         nan  35020
# ClmProcedureCode_3        40474    155         nan  39509
# ClmProcedureCode_4        40474     49         nan  40358
# ClmProcedureCode_5        40474      7         nan  40465
# ClmProcedureCode_6        40474      1         nan  40474
#
#                                                  mean                  min  \
# BeneID                                            NaN                  NaN
# ClaimID                                           NaN                  NaN
# ClaimStartDt            2009-06-19 17:46:36.284034048  2008-11-27 00:00:00
# ClaimEndDt              2009-06-25 09:37:21.972624384  2009-01-01 00:00:00
# Provider                                          NaN                  NaN
# InscClaimAmtReimbursed                   10087.884074                  0.0
# AttendingPhysician                                NaN                  NaN
# OperatingPhysician                                NaN                  NaN
# OtherPhysician                                    NaN                  NaN
# AdmissionDt             2009-06-19 17:38:12.493946880  2008-11-27 00:00:00
# ClmAdmitDiagnosisCode                             NaN                  NaN
# DeductibleAmtPaid                         1044.277808                  0.0
# DischargeDt             2009-06-25 09:36:02.988585216  2009-01-01 00:00:00
# DiagnosisGroupCode                                NaN                  NaN
# ClmDiagnosisCode_1                                NaN                  NaN
# ClmDiagnosisCode_2                                NaN                  NaN
# ClmDiagnosisCode_3                                NaN                  NaN
# ClmDiagnosisCode_4                                NaN                  NaN
# ClmDiagnosisCode_5                                NaN                  NaN
# ClmDiagnosisCode_6                                NaN                  NaN
# ClmDiagnosisCode_7                                NaN                  NaN
# ClmDiagnosisCode_8                                NaN                  NaN
# ClmDiagnosisCode_9                                NaN                  NaN
# ClmDiagnosisCode_10                               NaN                  NaN
# ClmProcedureCode_1                                NaN                  NaN
# ClmProcedureCode_2                                NaN                  NaN
# ClmProcedureCode_3                                NaN                  NaN
# ClmProcedureCode_4                                NaN                  NaN
# ClmProcedureCode_5                                NaN                  NaN
# ClmProcedureCode_6                                NaN                  NaN
#
#                                         25%                  50%  \
# BeneID                                  NaN                  NaN
# ClaimID                                 NaN                  NaN
# ClaimStartDt            2009-03-20 00:00:00  2009-06-16 00:00:00
# ClaimEndDt              2009-03-26 00:00:00  2009-06-22 00:00:00
# Provider                                NaN                  NaN
# InscClaimAmtReimbursed               4000.0               7000.0
# AttendingPhysician                      NaN                  NaN
# OperatingPhysician                      NaN                  NaN
# OtherPhysician                          NaN                  NaN
# AdmissionDt             2009-03-20 00:00:00  2009-06-16 00:00:00
# ClmAdmitDiagnosisCode                   NaN                  NaN
# DeductibleAmtPaid                    1068.0               1068.0
# DischargeDt             2009-03-26 00:00:00  2009-06-22 00:00:00
# DiagnosisGroupCode                      NaN                  NaN
# ClmDiagnosisCode_1                      NaN                  NaN
# ClmDiagnosisCode_2                      NaN                  NaN
# ClmDiagnosisCode_3                      NaN                  NaN
# ClmDiagnosisCode_4                      NaN                  NaN
# ClmDiagnosisCode_5                      NaN                  NaN
# ClmDiagnosisCode_6                      NaN                  NaN
# ClmDiagnosisCode_7                      NaN                  NaN
# ClmDiagnosisCode_8                      NaN                  NaN
# ClmDiagnosisCode_9                      NaN                  NaN
# ClmDiagnosisCode_10                     NaN                  NaN
# ClmProcedureCode_1                      NaN                  NaN
# ClmProcedureCode_2                      NaN                  NaN
# ClmProcedureCode_3                      NaN                  NaN
# ClmProcedureCode_4                      NaN                  NaN
# ClmProcedureCode_5                      NaN                  NaN
# ClmProcedureCode_6                      NaN                  NaN
#
#                                         75%                  max           std
# BeneID                                  NaN                  NaN           NaN
# ClaimID                                 NaN                  NaN           NaN
# ClaimStartDt            2009-09-17 00:00:00  2009-12-31 00:00:00           NaN
# ClaimEndDt              2009-09-23 00:00:00  2009-12-31 00:00:00           NaN
# Provider                                NaN                  NaN           NaN
# InscClaimAmtReimbursed              12000.0             125000.0  10303.099402
# AttendingPhysician                      NaN                  NaN           NaN
# OperatingPhysician                      NaN                  NaN           NaN
# OtherPhysician                          NaN                  NaN           NaN
# AdmissionDt             2009-09-17 00:00:00  2009-12-31 00:00:00           NaN
# ClmAdmitDiagnosisCode                   NaN                  NaN           NaN
# DeductibleAmtPaid                    1068.0               1068.0    157.394952
# DischargeDt             2009-09-23 00:00:00  2009-12-31 00:00:00           NaN
# DiagnosisGroupCode                      NaN                  NaN           NaN
# ClmDiagnosisCode_1                      NaN                  NaN           NaN
# ClmDiagnosisCode_2                      NaN                  NaN           NaN
# ClmDiagnosisCode_3                      NaN                  NaN           NaN
# ClmDiagnosisCode_4                      NaN                  NaN           NaN
# ClmDiagnosisCode_5                      NaN                  NaN           NaN
# ClmDiagnosisCode_6                      NaN                  NaN           NaN
# ClmDiagnosisCode_7                      NaN                  NaN           NaN
# ClmDiagnosisCode_8                      NaN                  NaN           NaN
# ClmDiagnosisCode_9                      NaN                  NaN           NaN
# ClmDiagnosisCode_10                     NaN                  NaN           NaN
# ClmProcedureCode_1                      NaN                  NaN           NaN
# ClmProcedureCode_2                      NaN                  NaN           NaN
# ClmProcedureCode_3                      NaN                  NaN           NaN
# ClmProcedureCode_4                      NaN                  NaN           NaN
# ClmProcedureCode_5                      NaN                  NaN           NaN
# ClmProcedureCode_6                      NaN                  NaN           NaN

# %%
for i in df_inp_conv.columns:
    print("++++++"+i+"+++++++++++++")
    print(df_inp_conv[i].value_counts())
# Out:
# ++++++BeneID+++++++++++++
# BeneID
# BENE134170    8
# BENE62091     7
# BENE117116    7
# BENE64791     7
# BENE121796    7
#              ..
# BENE158955    1
# BENE158959    1
# BENE158962    1
# BENE158963    1
# BENE158968    1
# Name: count, Length: 31289, dtype: int64
# ++++++ClaimID+++++++++++++
# ClaimID
# CLM69948    1
# CLM46614    1
# CLM66048    1
# CLM68358    1
# CLM38412    1
#            ..
# CLM60118    1
# CLM56288    1
# CLM63127    1
# CLM42596    1
# CLM35816    1
# Name: count, Length: 40474, dtype: int64
# ++++++ClaimStartDt+++++++++++++
# ClaimStartDt
# 2009-02-10    145
# 2009-02-26    144
# 2009-01-31    143
# 2009-01-06    139
# 2009-02-02    138
#              ...
# 2008-11-28      2
# 2008-12-03      1
# 2008-12-06      1
# 2009-12-31      1
# 2008-12-10      1
# Name: count, Length: 398, dtype: int64
# ++++++ClaimEndDt+++++++++++++
# ClaimEndDt
# 2009-02-11    153
# 2009-01-10    146
# 2009-03-03    144
# 2009-04-11    141
# 2009-05-31    138
#              ...
# 2009-11-29     82
# 2009-11-03     82
# 2009-10-19     79
# 2009-11-11     77
# 2009-12-25     75
# Name: count, Length: 365, dtype: int64
# ++++++Provider+++++++++++++
# Provider
# PRV52019    516
# PRV55462    386
# PRV54367    322
# PRV53706    282
# PRV55209    275
#            ...
# PRV57728      1
# PRV51248      1
# PRV56540      1
# PRV54673      1
# PRV53764      1
# Name: count, Length: 2092, dtype: int64
# ++++++InscClaimAmtReimbursed+++++++++++++
# InscClaimAmtReimbursed
# 4000      4506
# 5000      3996
# 3000      3852
# 6000      3318
# 7000      2837
#           ...
# 16600        1
# 84000        1
# 7020         1
# 117000       1
# 66000        1
# Name: count, Length: 146, dtype: int64
# ++++++AttendingPhysician+++++++++++++
# AttendingPhysician
# PHY422134    386
# PHY341560    274
# PHY315112    208
# PHY411541    198
# PHY431177    195
#             ...
# PHY335293      1
# PHY359755      1
# PHY353820      1
# PHY330717      1
# PHY319417      1
# Name: count, Length: 11604, dtype: int64
# ++++++OperatingPhysician+++++++++++++
# OperatingPhysician
# PHY429430    225
# PHY341560    153
# PHY411541    121
# PHY352941    110
# PHY314410    109
#             ...
# PHY331282      1
# PHY326541      1
# PHY367360      1
# PHY397228      1
# PHY312870      1
# Name: count, Length: 8287, dtype: int64
# ++++++OtherPhysician+++++++++++++
# OtherPhysician
# PHY416093    81
# PHY333406    38
# PHY429929    30
# PHY423728    29
# PHY361563    29
#              ..
# PHY389503     1
# PHY329089     1
# PHY419091     1
# PHY373199     1
# PHY424611     1
# Name: count, Length: 2877, dtype: int64
# ++++++AdmissionDt+++++++++++++
# AdmissionDt
# 2009-02-10    144
# 2009-02-26    143
# 2009-01-31    143
# 2009-01-06    140
# 2009-02-02    138
#              ...
# 2008-11-29      2
# 2008-12-06      1
# 2009-12-31      1
# 2008-12-03      1
# 2008-12-10      1
# Name: count, Length: 398, dtype: int64
# ++++++ClmAdmitDiagnosisCode+++++++++++++
# ClmAdmitDiagnosisCode
# 78650    1731
# 78605    1669
# 486      1438
# 4280     1106
# 7802     1018
#          ...
# 43381       1
# 94534       1
# 71897       1
# 1742        1
# 20302       1
# Name: count, Length: 1928, dtype: int64
# ++++++DeductibleAmtPaid+++++++++++++
# DeductibleAmtPaid
# 1068    39575
# 0         899
# Name: count, dtype: int64
# ++++++DischargeDt+++++++++++++
# DischargeDt
# 2009-02-11    153
# 2009-01-10    147
# 2009-03-03    143
# 2009-04-11    141
# 2009-02-14    138
#              ...
# 2009-11-29     82
# 2009-11-03     82
# 2009-10-19     79
# 2009-11-11     77
# 2009-12-25     75
# Name: count, Length: 365, dtype: int64
# ++++++DiagnosisGroupCode+++++++++++++
# DiagnosisGroupCode
# 882    179
# 884    174
# 166    168
# 183    165
# 939    163
#       ...
# 934      1
# 768      1
# 775      1
# 927      1
# 955      1
# Name: count, Length: 736, dtype: int64
# ++++++ClmDiagnosisCode_1+++++++++++++
# ClmDiagnosisCode_1
# 486      1499
# V5789    1158
# 41401    1088
# 49121     974
# 0389      945
#          ...
# 40599       1
# 55329       1
# 81602       1
# 1642        1
# 9592        1
# Name: count, Length: 2254, dtype: int64
# ++++++ClmDiagnosisCode_2+++++++++++++
# ClmDiagnosisCode_2
# 4019     2484
# 2724     1125
# 25000    1070
# 41401     806
# 42731     793
#          ...
# E9327       1
# 99594       1
# 71834       1
# 9678        1
# 30019       1
# Name: count, Length: 2439, dtype: int64
# ++++++ClmDiagnosisCode_3+++++++++++++
# ClmDiagnosisCode_3
# 4019     2282
# 25000    1108
# 2724     1097
# 4280      815
# 41401     741
#          ...
# 99939       1
# V109        1
# 20210       1
# 75169       1
# 5929        1
# Name: count, Length: 2427, dtype: int64
# ++++++ClmDiagnosisCode_4+++++++++++++
# ClmDiagnosisCode_4
# 4019     2100
# 2724     1028
# 25000    1015
# 41401     759
# 42731     747
#          ...
# 5940        1
# 72939       1
# 78721       1
# V1351       1
# 6179        1
# Name: count, Length: 2441, dtype: int64
# ++++++ClmDiagnosisCode_5+++++++++++++
# ClmDiagnosisCode_5
# 4019     1889
# 2724     1000
# 25000     978
# 41401     702
# 42731     694
#          ...
# 87363       1
# 41041       1
# 64813       1
# 64873       1
# E9800       1
# Name: count, Length: 2374, dtype: int64
# ++++++ClmDiagnosisCode_6+++++++++++++
# ClmDiagnosisCode_6
# 4019     1620
# 25000     911
# 2724      903
# 4280      692
# 42731     663
#          ...
# E8501       1
# 52800       1
# 43490       1
# 99645       1
# 53370       1
# Name: count, Length: 2358, dtype: int64
# ++++++ClmDiagnosisCode_7+++++++++++++
# ClmDiagnosisCode_7
# 4019     1402
# 25000     819
# 2724      803
# 41401     613
# 42731     608
#          ...
# 30021       1
# 1891        1
# 94222       1
# 80703       1
# 5832        1
# Name: count, Length: 2310, dtype: int64
# ++++++ClmDiagnosisCode_8+++++++++++++
# ClmDiagnosisCode_8
# 4019     1200
# 25000     697
# 2724      662
# 41401     553
# 4280      549
#          ...
# 30400       1
# V1252       1
# 99657       1
# 20201       1
# 7889        1
# Name: count, Length: 2243, dtype: int64
# ++++++ClmDiagnosisCode_9+++++++++++++
# ClmDiagnosisCode_9
# 4019     965
# 2724     633
# 25000    632
# 4280     494
# 42731    485
#         ...
# 79009      1
# 4539       1
# 35921      1
# 30720      1
# 78094      1
# Name: count, Length: 2094, dtype: int64
# ++++++ClmDiagnosisCode_10+++++++++++++
# ClmDiagnosisCode_10
# 4019     128
# 25000     90
# 2724      86
# 4280      81
# 41401     65
#         ...
# 71106      1
# 99883      1
# E8160      1
# 4329       1
# 78701      1
# Name: count, Length: 952, dtype: int64
# ++++++ClmProcedureCode_1+++++++++++++
# ClmProcedureCode_1
# nan       17326
# 9904.0     1137
# 8154.0     1021
# 66.0        893
# 3893.0      849
#           ...
# 5674.0        1
# 5104.0        1
# 7905.0        1
# 3121.0        1
# 6919.0        1
# Name: count, Length: 1118, dtype: int64
# ++++++ClmProcedureCode_2+++++++++++++
# ClmProcedureCode_2
# nan       35020
# 4019.0     1730
# 2724.0      837
# 5849.0      289
# 311.0       152
#           ...
# 436.0         1
# 9642.0        1
# 3699.0        1
# 9984.0        1
# 5799.0        1
# Name: count, Length: 298, dtype: int64
# ++++++ClmProcedureCode_3+++++++++++++
# ClmProcedureCode_3
# nan       39509
# 4019.0      201
# 2724.0      191
# 5849.0       42
# 4439.0       29
#           ...
# 7863.0        1
# 4532.0        1
# 4242.0        1
# 7804.0        1
# 7963.0        1
# Name: count, Length: 155, dtype: int64
# ++++++ClmProcedureCode_4+++++++++++++
# ClmProcedureCode_4
# nan       40358
# 4019.0       18
# 2724.0       16
# 4439.0        7
# 5849.0        6
# 4139.0        6
# 3572.0        4
# 2762.0        4
# 4011.0        3
# 5185.0        3
# 185.0         2
# 7804.0        2
# 311.0         2
# 2763.0        2
# 9974.0        2
# 496.0         2
# 42.0          2
# 4422.0        2
# 5845.0        2
# 3320.0        2
# 4269.0        1
# 1122.0        1
# 6822.0        1
# 4104.0        1
# 7999.0        1
# 7824.0        1
# 3963.0        1
# 5771.0        1
# 7823.0        1
# 2749.0        1
# 9986.0        1
# 7840.0        1
# 2761.0        1
# 4263.0        1
# 5121.0        1
# 7851.0        1
# 2752.0        1
# 4660.0        1
# 7802.0        1
# 3849.0        1
# 1511.0        1
# 4414.0        1
# 4240.0        1
# 5789.0        1
# 3962.0        1
# 5119.0        1
# 412.0         1
# 3844.0        1
# 3343.0        1
# Name: count, dtype: int64
# ++++++ClmProcedureCode_5+++++++++++++
# ClmProcedureCode_5
# nan       40465
# 4139.0        3
# 2724.0        2
# 5185.0        1
# 4422.0        1
# 9971.0        1
# 9982.0        1
# Name: count, dtype: int64
# ++++++ClmProcedureCode_6+++++++++++++
# ClmProcedureCode_6
# nan    40474
# Name: count, dtype: int64

# %% [markdown]
# 2. Feature addition for Inpatient file

# %%
def Feature_addition_inp_outp(df,type_of_data):
    df['Claim_period']=np.round(((df['ClaimEndDt'] - df['ClaimStartDt']).dt.days),1)
    df['Beneficiary_cost']=(df['InscClaimAmtReimbursed'] - df['DeductibleAmtPaid'])
    if type_of_data.lower()=='inpatient':
        diagnosis_code_columns = ['ClmDiagnosisCode_1','ClmDiagnosisCode_2','ClmDiagnosisCode_3','ClmDiagnosisCode_4',
                                'ClmDiagnosisCode_5','ClmDiagnosisCode_6','ClmDiagnosisCode_7','ClmDiagnosisCode_8','ClmDiagnosisCode_9','ClmDiagnosisCode_10']
        diagnosis_proc_columns = ['ClmProcedureCode_1','ClmProcedureCode_2','ClmProcedureCode_3']
                            
        df['Count_diag_code']=df[diagnosis_code_columns].notna().sum(axis=1)
        for i in diagnosis_proc_columns:
            df[i]=df[i].replace('nan', np.nan)
        df['Count_proc_code']=df[diagnosis_proc_columns].notna().sum(axis=1)
        df['Admit_Period']=np.round(((df['DischargeDt'] - df['AdmissionDt']).dt.days),1)
        df=df.drop(columns=['ClaimEndDt','ClaimStartDt','DischargeDt','AdmissionDt','ClmProcedureCode_6','ClmProcedureCode_4',
                                'ClmProcedureCode_5'],axis=1)
        df['Is_admit']=1
    elif type_of_data.lower().strip()=='outpatient':
        df['Claim_period']=np.round(((df['ClaimEndDt'] - df['ClaimStartDt']).dt.days),1)
        df['Beneficiary_cost']=(df['InscClaimAmtReimbursed'] - df['DeductibleAmtPaid'])
        diagnosis_code_columns = ['ClmDiagnosisCode_1','ClmDiagnosisCode_2','ClmDiagnosisCode_3','ClmDiagnosisCode_4',
                                    'ClmDiagnosisCode_5','ClmDiagnosisCode_6','ClmDiagnosisCode_7','ClmDiagnosisCode_8','ClmDiagnosisCode_9','ClmDiagnosisCode_10']
        diagnosis_proc_columns = ['ClmProcedureCode_1','ClmProcedureCode_2','ClmProcedureCode_3']
                                
        df['Count_diag_code']=df[diagnosis_code_columns].notna().sum(axis=1)
        for i in diagnosis_proc_columns:
                df[i]=df[i].replace('nan', np.nan)
        df['Count_proc_code']=df[diagnosis_proc_columns].notna().sum(axis=1)
        df=df.drop(columns=['ClaimEndDt','ClaimStartDt','ClmProcedureCode_6','ClmProcedureCode_4',
                                'ClmProcedureCode_5'],axis=1)
        df['Is_admit']=0
    return df

# %%
df_inp_conv=Feature_addition_inp_outp(df_inp_conv,'inpatient')

# %% [markdown]
# 3. Standardizing the code values

# %%
def pad_code(code):
    if pd.isna(code):
        return code  # Keep NaN as is
    return str(code).zfill(4)  # Pad with zeros to make it 4 characters

# %%
def diag_proccode_stnd(df):
    for i in [ 'ClmAdmitDiagnosisCode', 'DiagnosisGroupCode',
        'ClmDiagnosisCode_1', 'ClmDiagnosisCode_2', 'ClmDiagnosisCode_3',
        'ClmDiagnosisCode_4', 'ClmDiagnosisCode_5', 'ClmDiagnosisCode_6',
        'ClmDiagnosisCode_7', 'ClmDiagnosisCode_8', 'ClmDiagnosisCode_9',
        'ClmDiagnosisCode_10', 'ClmProcedureCode_1', 'ClmProcedureCode_2',
        'ClmProcedureCode_3']:
        df[i].astype(str)
        df[i]=df[i].replace(r'\.0$', '', regex=True)
        df[i]=df[i].replace(r'nan', np.nan, regex=True)
        df[i]=df[i].apply(pad_code)
        return df

# %%
df_inp_conv=diag_proccode_stnd(df_inp_conv)

# %%
df_inp_conv.columns
# Out:
# Index(['BeneID', 'ClaimID', 'Provider', 'InscClaimAmtReimbursed',
#        'AttendingPhysician', 'OperatingPhysician', 'OtherPhysician',
#        'ClmAdmitDiagnosisCode', 'DeductibleAmtPaid', 'DiagnosisGroupCode',
#        'ClmDiagnosisCode_1', 'ClmDiagnosisCode_2', 'ClmDiagnosisCode_3',
#        'ClmDiagnosisCode_4', 'ClmDiagnosisCode_5', 'ClmDiagnosisCode_6',
#        'ClmDiagnosisCode_7', 'ClmDiagnosisCode_8', 'ClmDiagnosisCode_9',
#        'ClmDiagnosisCode_10', 'ClmProcedureCode_1', 'ClmProcedureCode_2',
#        'ClmProcedureCode_3', 'ClmProcedureCode_4', 'ClmProcedureCode_5',
#        'Claim_period', 'Beneficiary_cost', 'Count_diag_code',
#        'Count_proc_code', 'Admit_Period', 'Is_admit'],
#       dtype='object')

# %%
df_inp_conv[['Claim_period','Admit_Period','Beneficiary_cost','Count_diag_code','Count_proc_code']].nunique()
# Out:
# Claim_period         37
# Admit_Period         36
# Beneficiary_cost    206
# Count_diag_code      10
# Count_proc_code       6
# dtype: int64

# %% [markdown]
# 4. Separating columns for analysis

# %%
def col_separation(dataset):
    cat_cols=dataset.select_dtypes('object').columns.to_list()
    int_cols=dataset.select_dtypes('int64').columns.to_list()
    time_cols=dataset.select_dtypes('datetime64[ns]').columns.to_list()
    return cat_cols,int_cols,time_cols

# %%
cat_cols=col_separation(df_inp_conv)[0]
int_cols=col_separation(df_inp_conv)[1]
tim_cols=col_separation(df_inp_conv)[2]

# %% [markdown]
# 5. Univariate Analysis

# %%
num_univariate(df_inp_conv)

# %%
cat_columns_univariate(df_inp_conv)

# %% [markdown]
# 6. Outlier Analysis

# %%
outlier_analysis(df_inp_conv)

# %% [markdown]
# **Out patient**

# %%
df_outp.dtypes
# Out:
# BeneID                     object
# ClaimID                    object
# ClaimStartDt               object
# ClaimEndDt                 object
# Provider                   object
# InscClaimAmtReimbursed      int64
# AttendingPhysician         object
# OperatingPhysician         object
# OtherPhysician             object
# ClmDiagnosisCode_1         object
# ClmDiagnosisCode_2         object
# ClmDiagnosisCode_3         object
# ClmDiagnosisCode_4         object
# ClmDiagnosisCode_5         object
# ClmDiagnosisCode_6         object
# ClmDiagnosisCode_7         object
# ClmDiagnosisCode_8         object
# ClmDiagnosisCode_9         object
# ClmDiagnosisCode_10        object
# ClmProcedureCode_1        float64
# ClmProcedureCode_2        float64
# ClmProcedureCode_3        float64
# ClmProcedureCode_4        float64
# ClmProcedureCode_5        float64
# ClmProcedureCode_6        float64
# DeductibleAmtPaid           int64
# ClmAdmitDiagnosisCode      object
# dtype: object

# %%
df_outp.describe(include='all').T
# Out:
#                            count  unique         top   freq         mean  \
# BeneID                    517737  133980   BENE42721     29          NaN
# ClaimID                   517737  517737   CLM686139      1          NaN
# ClaimStartDt              517737     385  2009-03-03   1574          NaN
# ClaimEndDt                517737     366  2009-03-03   1563          NaN
# Provider                  517737    5012    PRV51459   8240          NaN
# InscClaimAmtReimbursed  517737.0     NaN         NaN    NaN   286.334799
# AttendingPhysician        516341   74109   PHY330576   2534          NaN
# OperatingPhysician         90617   28532   PHY330576    424          NaN
# OtherPhysician            195046   44388   PHY412132   1247          NaN
# ClmDiagnosisCode_1        507284   10354        4019  13803          NaN
# ClmDiagnosisCode_2        322357    5056        4019  19894          NaN
# ClmDiagnosisCode_3        203257    4448        4019  12126          NaN
# ClmDiagnosisCode_4        125596    3925        4019   7088          NaN
# ClmDiagnosisCode_5         74344    3412        4019   4116          NaN
# ClmDiagnosisCode_6         48756    2968        4019   2550          NaN
# ClmDiagnosisCode_7         32961    2635        4019   1612          NaN
# ClmDiagnosisCode_8         22912    2260        4019   1057          NaN
# ClmDiagnosisCode_9         14838    1894        4019    616          NaN
# ClmDiagnosisCode_10         1083     495        4019     41          NaN
# ClmProcedureCode_1         162.0     NaN         NaN    NaN  6116.611111
# ClmProcedureCode_2          36.0     NaN         NaN    NaN  4503.277778
# ClmProcedureCode_3           4.0     NaN         NaN    NaN       2959.0
# ClmProcedureCode_4           2.0     NaN         NaN    NaN       4075.5
# ClmProcedureCode_5           0.0     NaN         NaN    NaN          NaN
# ClmProcedureCode_6           0.0     NaN         NaN    NaN          NaN
# DeductibleAmtPaid       517737.0     NaN         NaN    NaN     2.779233
# ClmAdmitDiagnosisCode     105425    3715       V7612   4074          NaN
#
#                                 std    min      25%     50%      75%       max
# BeneID                          NaN    NaN      NaN     NaN      NaN       NaN
# ClaimID                         NaN    NaN      NaN     NaN      NaN       NaN
# ClaimStartDt                    NaN    NaN      NaN     NaN      NaN       NaN
# ClaimEndDt                      NaN    NaN      NaN     NaN      NaN       NaN
# Provider                        NaN    NaN      NaN     NaN      NaN       NaN
# InscClaimAmtReimbursed   694.034343    0.0     40.0    80.0    200.0  102500.0
# AttendingPhysician              NaN    NaN      NaN     NaN      NaN       NaN
# OperatingPhysician              NaN    NaN      NaN     NaN      NaN       NaN
# OtherPhysician                  NaN    NaN      NaN     NaN      NaN       NaN
# ClmDiagnosisCode_1              NaN    NaN      NaN     NaN      NaN       NaN
# ClmDiagnosisCode_2              NaN    NaN      NaN     NaN      NaN       NaN
# ClmDiagnosisCode_3              NaN    NaN      NaN     NaN      NaN       NaN
# ClmDiagnosisCode_4              NaN    NaN      NaN     NaN      NaN       NaN
# ClmDiagnosisCode_5              NaN    NaN      NaN     NaN      NaN       NaN
# ClmDiagnosisCode_6              NaN    NaN      NaN     NaN      NaN       NaN
# ClmDiagnosisCode_7              NaN    NaN      NaN     NaN      NaN       NaN
# ClmDiagnosisCode_8              NaN    NaN      NaN     NaN      NaN       NaN
# ClmDiagnosisCode_9              NaN    NaN      NaN     NaN      NaN       NaN
# ClmDiagnosisCode_10             NaN    NaN      NaN     NaN      NaN       NaN
# ClmProcedureCode_1      3217.719258   51.0   3893.0  5244.5   9421.5    9999.0
# ClmProcedureCode_2         2504.015  412.0   2724.0  4019.0   5849.0    9982.0
# ClmProcedureCode_3      1863.455393  412.0   2146.0  3511.5   4324.5    4401.0
# ClmProcedureCode_4      5323.806956  311.0  2193.25  4075.5  5957.75    7840.0
# ClmProcedureCode_5              NaN    NaN      NaN     NaN      NaN       NaN
# ClmProcedureCode_6              NaN    NaN      NaN     NaN      NaN       NaN
# DeductibleAmtPaid         15.785839    0.0      0.0     0.0      0.0     897.0
# ClmAdmitDiagnosisCode           NaN    NaN      NaN     NaN      NaN       NaN

# %%
df_outp.dtypes
# Out:
# BeneID                     object
# ClaimID                    object
# ClaimStartDt               object
# ClaimEndDt                 object
# Provider                   object
# InscClaimAmtReimbursed      int64
# AttendingPhysician         object
# OperatingPhysician         object
# OtherPhysician             object
# ClmDiagnosisCode_1         object
# ClmDiagnosisCode_2         object
# ClmDiagnosisCode_3         object
# ClmDiagnosisCode_4         object
# ClmDiagnosisCode_5         object
# ClmDiagnosisCode_6         object
# ClmDiagnosisCode_7         object
# ClmDiagnosisCode_8         object
# ClmDiagnosisCode_9         object
# ClmDiagnosisCode_10        object
# ClmProcedureCode_1        float64
# ClmProcedureCode_2        float64
# ClmProcedureCode_3        float64
# ClmProcedureCode_4        float64
# ClmProcedureCode_5        float64
# ClmProcedureCode_6        float64
# DeductibleAmtPaid           int64
# ClmAdmitDiagnosisCode      object
# dtype: object

# %%
df_outp_conv=type_conv(df_outp,config_data,"datetime_columns_outp","obj_columns_outp","int_columns_outp")

# %% [markdown]
# 1. Feature addition for outpatient file

# %%
df_outp_conv=Feature_addition_inp_outp(df_outp_conv,'outpatient')

# %%
df_outp_conv=diag_proccode_stnd(df_outp_conv)

# %%
len(df_outp)
# Out:
# 517737

# %%
df_outp_conv.isna().sum()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /Users/Geethika/Documents/GitHub/Medicare Claims/Medicare_file_load_preprocessing.ipynb Cell 67 line 1
# ----> <a href='vscode-notebook-cell:/Users/Geethika/Documents/GitHub/Medicare%20Claims/Medicare_file_load_preprocessing.ipynb#Y123sZmlsZQ%3D%3D?line=0'>1</a> df_outp_conv.isna().sum()
#
# NameError: name 'df_outp_conv' is not defined

# %%
df_outp_conv['ClmProcedureCode_6'].nunique
# Out:
# <bound method IndexOpsMixin.nunique of 0         nan
# 1         nan
# 2         nan
# 3         nan
# 4         nan
#          ...
# 517732    nan
# 517733    nan
# 517734    nan
# 517735    nan
# 517736    nan
# Name: ClmProcedureCode_6, Length: 517737, dtype: object>

# %%
cat_cols=col_separation(df_outp_conv)[0]
int_cols=col_separation(df_outp_conv)[1]
tim_cols=col_separation(df_outp_conv)[2]

# %%
num_univariate(df_outp_conv)

# %%
outlier_analysis(df_outp_conv)

# %%
cat_columns_univariate(df_outp_conv)

# %% [markdown]
# **Merging Files - Inpatient and outpatient**

# %%
util.pickle_dump(df_ben_conv, config_data["raw_dataset_path_train_ben"])
util.pickle_dump(df_inp_conv, config_data["raw_dataset_path_train_inp"])
util.pickle_dump(df_outp_conv, config_data["raw_dataset_path_train_outp"])
